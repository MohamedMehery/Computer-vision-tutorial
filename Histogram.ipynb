# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("girl.bmp" , 1)
hist = cv2.calcHist( [img] , [0] , None , [256] , [0,256])
#hist,bins = np.histogram(img.ravel(),256,[0,256])
plt.hist(img.ravel() , 256 , [0,256] );plt.xlim([0,256]);plt.show()
color = ('b','g','r') #as the image has three colors , if gray it won't work
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

#equalization
img = cv2.imread("girl.bmp" , 0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
#cv2.imshow("original" , img)
plt.imshow(img)
plt.imshow(res)

cv2.imshow("equalized" , res)

#cv2.imwrite('RGBY.png',res)
